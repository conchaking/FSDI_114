# %%
help([])
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
# ...

# %%
class SinglyLinkedList: 
    class __Node: 
        def __init__(self, data):
            self.data = data
            self.next = None

    def __init__(self):
        self.head = None

    def append(self, value):
        new_node = self.__Node(value)
        if not self.head:               # this is how we check if the list is empty
            self.head = new_node
        else:
            current = self.head
            while current.next:         # while current.next is not equal to None
                current = current.next
            current.next = new_node

    
    def insert(self, index, value):
        new_node = self.__Node(value)
        if not self.head:
            self.head = new_node
        else: 
            current = self.head
            counter = 0
            prev = None
            while index != counter and current.next:
                prev = current
                current = current.next
                counter += 1
            if index == 0:
                # replace the head
                new_node.next = self.head
                self.head = new_node
            elif current.next:
                if index == counter:
                    prev.next = new_node
                    new_node.next = current
            else:
                current.next = new_node

    def remove(self, value):
        # this should remove the first instance of vaule in our list; ValueError if not found
        pass

    def index(self, value):
        # this should return the position of "value" in our list; IndexError if not found
        pass

    def __len__(self):
        # this should return the number of elements in our list
        pass

    def __str__(self):
        out = "["
        current = self.head
        if self.head:
            out += "%s" % current.data
            current = current.next
            while current:
                out += ", %s" & current.data
                current = current.next
        out += "]"
        return out

# %%
mylist = [] # not my list; This is a Python list. 
sll = SinglyLinkedList()

# if the list is empty:
print(mylist)
print("My list: %s" % sll)

# if the list contains only one element:
mylist.append(1)
sll.append(1)
print(mylist)
print("My list: %s" % sll)

# if the list contains more than one element:
mylist.append(2)
sll.append(2)
print(mylist)
print(sll)

# more data
for number in range (2, 6):
    mylist.append(number) 
    sll.append(number)

print(mylist)
print(sll)
# Out:
# []
# My list: []
# [1]
# My list: [1]
# [1, 2]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 18
#      16 sll.append(2)
#      17 print(mylist)
# ---> 18 print(sll)
#      20 # more data
#      21 for number in range (2, 6):
#
# Cell In[5], line 40, in SinglyLinkedList.__str__(self)
#      38     current = current.next
#      39     while current:
# ---> 40         out += ", %s" & current.data
#      41         current = current.next
#      42 out += "]"
#
# TypeError: unsupported operand type(s) for &: 'str' and 'int'

# %%
mylist = []

mylist.insert(0, 1)

print(mylist)

mylist.insert(1000, 2)

print(mylist)
